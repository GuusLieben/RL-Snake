# %%
# %matplotlib notebook
# %run base.py

# %%
# %matplotlib notebook
# %run expert.py

# %%
# %matplotlib notebook
# %run dqn.py train=False steps=100

# %%
# %matplotlib notebook
# %run ppo2.py train=False
# Out:
# Using properties:
# -  train : False
# -  steps : 200
# -  grid_size : 6
# Loading a model without an environment, this model cannot be trained until it has a valid environment.
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
# %run ddpg.py
