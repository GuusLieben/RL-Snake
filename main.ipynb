# %%
# %matplotlib notebook
# %run base.py

# %%
# %matplotlib notebook
# %run expert.py

# %%
# %matplotlib notebook
# %run dqn.py exploration_factor=0.2 exploration_min=0.25

# %%
# %matplotlib notebook
# %run dqn.py train=False steps=500
# Out:
# Using properties:
# -  train : False
# -  steps : 500
# -  learning_rate : 0.001
# -  double_q : True
# -  grid_size : 6
# -  exploration_factor : 0.1
# -  exploration_min : 0.02
# -  total_steps : 400000
# Loading a model without an environment, this model cannot be trained until it has a valid environment.
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# A:\Avans\RL-Snake\dqn.py in <module>
#      70         obs, reward, done, info = env.step(action)
#      71         if not training:
# ---> 72             env.render()
#      73 env.close()
#
# A:\Avans\RL-Snake\gym_snake\envs\snake_env.py in render(self, mode, close, frame_speed)
#     131             self.viewer.clear()
#     132             self.viewer.imshow(self.last_obs)
# --> 133             plt.pause(frame_speed)
#     134         self.fig.canvas.draw()
#     135
#
# ...
