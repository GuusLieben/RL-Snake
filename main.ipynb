# %% [markdown]
# # Base implementation

# %%
# %matplotlib notebook
# %run base.py
# Out:
# C:\Users\Jeremy\anaconda3\envs\py37\lib\site-packages\ale_py\roms\utils.py:90: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for external in metadata.entry_points().get(self.group, []):
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Expert snake (Hardcoded)
# ```py
# def make_move(x_snek, y_snek, x_apple, y_apple, matrix):
#     if y_snek % 2 == 0:
#         if x_snek == grid_size - 1:
#             return DOWN
#         if x_snek == 0 and y_snek != 0:
#             return UP
#         return RIGHT
#     else:
#         if x_snek == 0:
#             return UP
#         if x_snek == 1 and y_snek != grid_size - 1:
#             return DOWN
#         return LEFT
# ```
# ![flow](https://datagenetics.com/blog/april42013/g.png)

# %%
# %matplotlib notebook
# %run expert.py
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # RL algorithm DQN

# %% [markdown]
# - train (training mode or use an existing model )
# - learning_rate (0.001)
# - double_q (True)
# - grid_size (6)
# - exploration_factor (0.1)
# - exploration_min (0.02, digit * 100 percentage)
# - total_steps (400k)
# - load_model (load modal as train=False)

# %%
# %matplotlib notebook
# %run dqn.py exploration_factor=0.2 exploration_min=0.25
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Using properties:
# -  train : True
# -  steps : 30
# -  learning_rate : 0.001
# -  double_q : True
# -  grid_size : 6
# -  exploration_factor : 0.2
# -  exploration_min : 0.25
# -  total_steps : 400000
# -  load_model : None
# WARNING:tensorflow:From C:\Users\Jeremy\anaconda3\envs\py37\lib\site-packages\stable_baselines\common\tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\Jeremy\anaconda3\envs\py37\lib\site-packages\stable_baselines\common\tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From C:\Users\Jeremy\anaconda3\envs\py37\lib\site-packages\stable_baselines\deepq\dqn.py:129: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From C:\Users\Jeremy\anaconda3\envs\py37\lib\site-packages\stable_baselines\deepq\build_graph.py:358: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From C:\Users\Jeremy\anaconda3\envs\py37\lib\site-packages\stable_baselines\deepq\build_graph.py:359: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\Jeremy\anaconda3\envs\py37\lib\site-packages\stable_baselines\deepq\build_graph.py:139: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From C:\Users\Jeremy\anaconda3\envs\py37\lib\site-packages\stable_baselines\deepq\policies.py:109: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From C:\Users\Jeremy\anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\layers\core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From C:\Users\Jeremy\anaconda3\envs\py37\lib\site-packages\stable_baselines\deepq\build_graph.py:147: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\Jeremy\anaconda3\envs\py37\lib\site-packages\stable_baselines\deepq\build_graph.py:149: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\Jeremy\anaconda3\envs\py37\lib\site-packages\stable_baselines\deepq\build_graph.py:372: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From C:\Users\Jeremy\anaconda3\envs\py37\lib\site-packages\stable_baselines\deepq\build_graph.py:372: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From C:\Users\Jeremy\anaconda3\envs\py37\lib\site-packages\stable_baselines\deepq\build_graph.py:372: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
# C:\Users\Jeremy\anaconda3\envs\py37\lib\site-packages\stable_baselines\__init__.py:33: UserWarning: stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation.
#   "stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation."
# WARNING:tensorflow:From C:\Users\Jeremy\anaconda3\envs\py37\lib\site-packages\stable_baselines\deepq\build_graph.py:415: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From C:\Users\Jeremy\anaconda3\envs\py37\lib\site-packages\stable_baselines\deepq\build_graph.py:449: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From C:\Users\Jeremy\anaconda3\envs\py37\lib\site-packages\stable_baselines\common\tf_util.py:241: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Users\Jeremy\anaconda3\envs\py37\lib\site-packages\stable_baselines\common\tf_util.py:242: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From C:\Users\Jeremy\anaconda3\envs\py37\lib\site-packages\stable_baselines\common\base_class.py:1169: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From C:\Users\Jeremy\anaconda3\envs\py37\lib\site-packages\stable_baselines\common\tf_util.py:322: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Users\Jeremy\anaconda3\envs\py37\lib\site-packages\stable_baselines\common\tf_util.py:502: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# --------------------------------------
# | % time spent exploring  | 99       |
# | episodes                | 100      |
# | mean 100 episode reward | -0.9     |
# | steps                   | 682      |
# --------------------------------------
# WARNING:tensorflow:From C:\Users\Jeremy\anaconda3\envs\py37\lib\site-packages\stable_baselines\deepq\dqn.py:284: The name tf.RunOptions is deprecated. Please use tf.compat.v1.RunOptions instead.
#
# WARNING:tensorflow:From C:\Users\Jeremy\anaconda3\envs\py37\lib\site-packages\stable_baselines\deepq\dqn.py:285: The name tf.RunMetadata is deprecated. Please use tf.compat.v1.RunMetadata instead.
#
# --------------------------------------
# | % time spent exploring  | 98       |
# | episodes                | 200      |
# | mean 100 episode reward | -0.8     |
# | steps                   | 1486     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 97       |
# | episodes                | 300      |
# | mean 100 episode reward | -0.8     |
# | steps                   | 2292     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 97       |
# | episodes                | 400      |
# | mean 100 episode reward | -0.9     |
# | steps                   | 3034     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 96       |
# | episodes                | 500      |
# | mean 100 episode reward | -0.8     |
# | steps                   | 3819     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 95       |
# | episodes                | 600      |
# | mean 100 episode reward | -0.9     |
# | steps                   | 4563     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 94       |
# | episodes                | 700      |
# | mean 100 episode reward | -0.8     |
# | steps                   | 5396     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 94       |
# | episodes                | 800      |
# | mean 100 episode reward | -0.8     |
# | steps                   | 6221     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 93       |
# | episodes                | 900      |
# | mean 100 episode reward | -0.8     |
# | steps                   | 7039     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 92       |
# | episodes                | 1000     |
# | mean 100 episode reward | -0.8     |
# | steps                   | 7825     |
# --------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\School\RL-Snake\dqn.py in <module>
#      64                 exploration_final_eps=float(properties['exploration_min']),
#      65                 exploration_fraction=float(properties['exploration_factor']))
# ---> 66     model.learn(total_timesteps=int(properties['total_steps']))
#      67     model.save('learned_models/last_dqn')
#      68 else:
#
# ~\anaconda3\envs\py37\lib\site-packages\stable_baselines\deepq\dqn.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, replay_wrapper)
#     214                     kwargs['update_param_noise_scale'] = True
#     215                 with self.sess.as_default():
# --> 216                     action = self.act(np.array(obs)[None], update_eps=update_eps, **kwargs)[0]
#     217                 env_action = action
#     218                 reset = False
#
# ~\anaconda3\envs\py37\lib\site-packages\stable_baselines\deepq\build_graph.py in act(obs, stochastic, update_eps)
#     157
#     158     def act(obs, stochastic=True, update_eps=-1):
# --> 159         return _act(obs, stochastic, update_eps)
#     160
#     161     return act, obs_phs
#
# ~\anaconda3\envs\py37\lib\site-packages\stable_baselines\common\tf_util.py in <lambda>(*args, **kwargs)
#     285     else:
#     286         func = _Function(inputs, [outputs], updates, givens=givens)
# --> 287         return lambda *args, **kwargs: func(*args, **kwargs)[0]
#     288
#     289
#
# ~\anaconda3\envs\py37\lib\site-packages\stable_baselines\common\tf_util.py in __call__(self, sess, *args, **kwargs)
#     328         for inpt in self.givens:
#     329             feed_dict[inpt] = feed_dict.get(inpt, self.givens[inpt])
# --> 330         results = sess.run(self.outputs_update, feed_dict=feed_dict, **kwargs)[:-1]
#     331         return results
#     332
#
# ~\anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# ~\anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\client\session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# ~\anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~\anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# # RL algorithm PPO2

# %%
# %matplotlib notebook
# %run ppo2.py
# Out:
# Using properties:
# -  train : True
# -  steps : 200
# -  grid_size : 6
# -  n_steps : 128
# -  load_model : None
# Wrapping the env in a DummyVecEnv.
# --------------------------------------
# | approxkl           | 7.358994e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0544       |
# | fps                | 519           |
# | n_updates          | 1             |
# | policy_entropy     | 1.3862116     |
# | policy_loss        | -0.0030832165 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 0             |
# | total_timesteps    | 128           |
# | value_loss         | 1.7126203     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.0935178e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.139        |
# | fps                | 1376          |
# | n_updates          | 2             |
# | policy_entropy     | 1.3860527     |
# | policy_loss        | -0.0018472956 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 0.25          |
# | total_timesteps    | 256           |
# | value_loss         | 0.92979014    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.2540627e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0295        |
# | fps                | 1340          |
# | n_updates          | 3             |
# | policy_entropy     | 1.3858658     |
# | policy_loss        | -0.0015431757 |
# | serial_timesteps   | 384           |
# | time_elapsed       | 0.346         |
# | total_timesteps    | 384           |
# | value_loss         | 1.4741741     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.4598484e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00758       |
# | fps                | 1361          |
# | n_updates          | 4             |
# | policy_entropy     | 1.3855686     |
# | policy_loss        | -0.0027971473 |
# | serial_timesteps   | 512           |
# | time_elapsed       | 0.444         |
# | total_timesteps    | 512           |
# | value_loss         | 2.852246      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.0359664e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.131        |
# | fps                | 1347          |
# | n_updates          | 5             |
# | policy_entropy     | 1.3851941     |
# | policy_loss        | -0.0024563575 |
# | serial_timesteps   | 640           |
# | time_elapsed       | 0.54          |
# | total_timesteps    | 640           |
# | value_loss         | 0.5261511     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.4935118e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0447       |
# | fps                | 1391          |
# | n_updates          | 6             |
# | policy_entropy     | 1.3848716     |
# | policy_loss        | -0.001536374  |
# | serial_timesteps   | 768           |
# | time_elapsed       | 0.638         |
# | total_timesteps    | 768           |
# | value_loss         | 1.8533932     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.6862755e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0512       |
# | fps                | 1376          |
# | n_updates          | 7             |
# | policy_entropy     | 1.3839492     |
# | policy_loss        | -0.0028433814 |
# | serial_timesteps   | 896           |
# | time_elapsed       | 0.733         |
# | total_timesteps    | 896           |
# | value_loss         | 0.7967287     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.5070166e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00465       |
# | fps                | 1371          |
# | n_updates          | 8             |
# | policy_entropy     | 1.3833544     |
# | policy_loss        | -0.0023606948 |
# | serial_timesteps   | 1024          |
# | time_elapsed       | 0.828         |
# | total_timesteps    | 1024          |
# | value_loss         | 2.0309463     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.81143e-05   |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0745       |
# | fps                | 1391          |
# | n_updates          | 9             |
# | policy_entropy     | 1.3825226     |
# | policy_loss        | -0.0035308523 |
# | serial_timesteps   | 1152          |
# | time_elapsed       | 0.923         |
# | total_timesteps    | 1152          |
# | value_loss         | 0.61595416    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.4065356e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0532       |
# | fps                | 1376          |
# | n_updates          | 10            |
# | policy_entropy     | 1.3802538     |
# | policy_loss        | -0.0033654138 |
# | serial_timesteps   | 1280          |
# | time_elapsed       | 1.02          |
# | total_timesteps    | 1280          |
# | value_loss         | 0.94595796    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.7319317e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0347       |
# | fps                | 1376          |
# | n_updates          | 11            |
# | policy_entropy     | 1.3793764     |
# | policy_loss        | -0.001771882  |
# | serial_timesteps   | 1408          |
# | time_elapsed       | 1.11          |
# | total_timesteps    | 1408          |
# | value_loss         | 1.6012117     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.9392114e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0633        |
# | fps                | 1361          |
# | n_updates          | 12            |
# | policy_entropy     | 1.3773736     |
# | policy_loss        | -0.0024657832 |
# | serial_timesteps   | 1536          |
# | time_elapsed       | 1.21          |
# | total_timesteps    | 1536          |
# | value_loss         | 1.2185284     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00012637468 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00843      |
# | fps                | 1376          |
# | n_updates          | 13            |
# | policy_entropy     | 1.37787       |
# | policy_loss        | -0.0035501788 |
# | serial_timesteps   | 1664          |
# | time_elapsed       | 1.31          |
# | total_timesteps    | 1664          |
# | value_loss         | 0.9268075     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.626927e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0145        |
# | fps                | 1347          |
# | n_updates          | 14            |
# | policy_entropy     | 1.3770258     |
# | policy_loss        | -0.0028397497 |
# | serial_timesteps   | 1792          |
# | time_elapsed       | 1.4           |
# | total_timesteps    | 1792          |
# | value_loss         | 1.1758084     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 3.756365e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.276       |
# | fps                | 1376         |
# | n_updates          | 15           |
# | policy_entropy     | 1.3757509    |
# | policy_loss        | -0.002109504 |
# | serial_timesteps   | 1920         |
# | time_elapsed       | 1.5          |
# | total_timesteps    | 1920         |
# | value_loss         | 0.38661295   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 2.5302696e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.094        |
# | fps                | 1422          |
# | n_updates          | 16            |
# | policy_entropy     | 1.3771429     |
# | policy_loss        | -0.0010570904 |
# | serial_timesteps   | 2048          |
# | time_elapsed       | 1.59          |
# | total_timesteps    | 2048          |
# | value_loss         | 2.2779539     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.5263547e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0549        |
# | fps                | 1376          |
# | n_updates          | 17            |
# | policy_entropy     | 1.3763666     |
# | policy_loss        | -0.002779841  |
# | serial_timesteps   | 2176          |
# | time_elapsed       | 1.69          |
# | total_timesteps    | 2176          |
# | value_loss         | 0.964121      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.3206662e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0189       |
# | fps                | 1376          |
# | n_updates          | 18            |
# | policy_entropy     | 1.376494      |
# | policy_loss        | -0.0016804475 |
# | serial_timesteps   | 2304          |
# | time_elapsed       | 1.78          |
# | total_timesteps    | 2304          |
# | value_loss         | 1.4489377     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.4423857e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0274        |
# | fps                | 1378          |
# | n_updates          | 19            |
# | policy_entropy     | 1.3763629     |
# | policy_loss        | -0.0028340146 |
# | serial_timesteps   | 2432          |
# | time_elapsed       | 1.88          |
# | total_timesteps    | 2432          |
# | value_loss         | 1.1935546     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.2831547e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00748       |
# | fps                | 1336          |
# | n_updates          | 20            |
# | policy_entropy     | 1.375662      |
# | policy_loss        | -0.0013342119 |
# | serial_timesteps   | 2560          |
# | time_elapsed       | 1.97          |
# | total_timesteps    | 2560          |
# | value_loss         | 1.8986576     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00014258121 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.123        |
# | fps                | 1360          |
# | n_updates          | 21            |
# | policy_entropy     | 1.3749887     |
# | policy_loss        | -0.0052167918 |
# | serial_timesteps   | 2688          |
# | time_elapsed       | 2.07          |
# | total_timesteps    | 2688          |
# | value_loss         | 0.64709806    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00017898405 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0553       |
# | fps                | 1361          |
# | n_updates          | 22            |
# | policy_entropy     | 1.3731774     |
# | policy_loss        | -0.0048866994 |
# | serial_timesteps   | 2816          |
# | time_elapsed       | 2.17          |
# | total_timesteps    | 2816          |
# | value_loss         | 0.91013056    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00013874493 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0717        |
# | fps                | 1376          |
# | n_updates          | 23            |
# | policy_entropy     | 1.3699379     |
# | policy_loss        | -0.0044253124 |
# | serial_timesteps   | 2944          |
# | time_elapsed       | 2.26          |
# | total_timesteps    | 2944          |
# | value_loss         | 0.8855523     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.000109192726 |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0944         |
# | fps                | 1376           |
# | n_updates          | 24             |
# | policy_entropy     | 1.366609       |
# | policy_loss        | -0.0040425765  |
# | serial_timesteps   | 3072           |
# | time_elapsed       | 2.36           |
# | total_timesteps    | 3072           |
# | value_loss         | 0.8770809      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 4.1355444e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.00592       |
# | fps                | 1391           |
# | n_updates          | 25             |
# | policy_entropy     | 1.3684324      |
# | policy_loss        | -0.00093171664 |
# | serial_timesteps   | 3200           |
# | time_elapsed       | 2.46           |
# | total_timesteps    | 3200           |
# | value_loss         | 2.7571566      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 7.511882e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0965        |
# | fps                | 1361          |
# | n_updates          | 26            |
# | policy_entropy     | 1.3642612     |
# | policy_loss        | -0.0030895902 |
# | serial_timesteps   | 3328          |
# | time_elapsed       | 2.55          |
# | total_timesteps    | 3328          |
# | value_loss         | 0.9327527     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.877069e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0061        |
# | fps                | 1391          |
# | n_updates          | 27            |
# | policy_entropy     | 1.3626771     |
# | policy_loss        | -0.0035089606 |
# | serial_timesteps   | 3456          |
# | time_elapsed       | 2.65          |
# | total_timesteps    | 3456          |
# | value_loss         | 0.7131768     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00015246075 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.129         |
# | fps                | 1347          |
# | n_updates          | 28            |
# | policy_entropy     | 1.3539917     |
# | policy_loss        | -0.0030318578 |
# | serial_timesteps   | 3584          |
# | time_elapsed       | 2.74          |
# | total_timesteps    | 3584          |
# | value_loss         | 1.1225843     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00013884169 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.116         |
# | fps                | 1361          |
# | n_updates          | 29            |
# | policy_entropy     | 1.3539963     |
# | policy_loss        | -0.0037320557 |
# | serial_timesteps   | 3712          |
# | time_elapsed       | 2.84          |
# | total_timesteps    | 3712          |
# | value_loss         | 0.7155274     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.664954e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0303        |
# | fps                | 1391          |
# | n_updates          | 30            |
# | policy_entropy     | 1.3588034     |
# | policy_loss        | -0.0020542904 |
# | serial_timesteps   | 3840          |
# | time_elapsed       | 2.94          |
# | total_timesteps    | 3840          |
# | value_loss         | 0.91648114    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00014504037 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.000867      |
# | fps                | 1391          |
# | n_updates          | 31            |
# | policy_entropy     | 1.355277      |
# | policy_loss        | -0.005120555  |
# | serial_timesteps   | 3968          |
# | time_elapsed       | 3.03          |
# | total_timesteps    | 3968          |
# | value_loss         | 1.482411      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00010474924 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.027         |
# | fps                | 1361          |
# | n_updates          | 32            |
# | policy_entropy     | 1.3538167     |
# | policy_loss        | -0.003722847  |
# | serial_timesteps   | 4096          |
# | time_elapsed       | 3.13          |
# | total_timesteps    | 4096          |
# | value_loss         | 0.58774656    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.111891e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0269        |
# | fps                | 1391          |
# | n_updates          | 33            |
# | policy_entropy     | 1.3505695     |
# | policy_loss        | -0.0036269587 |
# | serial_timesteps   | 4224          |
# | time_elapsed       | 3.22          |
# | total_timesteps    | 4224          |
# | value_loss         | 2.1523354     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 8.189093e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.0156      |
# | fps                | 1376         |
# | n_updates          | 34           |
# | policy_entropy     | 1.3473963    |
# | policy_loss        | -0.00305308  |
# | serial_timesteps   | 4352         |
# | time_elapsed       | 3.32         |
# | total_timesteps    | 4352         |
# | value_loss         | 0.76853305   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00011973579 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.151         |
# | fps                | 1361          |
# | n_updates          | 35            |
# | policy_entropy     | 1.3509728     |
# | policy_loss        | -0.0029363055 |
# | serial_timesteps   | 4480          |
# | time_elapsed       | 3.41          |
# | total_timesteps    | 4480          |
# | value_loss         | 0.784775      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00029004013 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0126       |
# | fps                | 1376          |
# | n_updates          | 36            |
# | policy_entropy     | 1.3503923     |
# | policy_loss        | -0.007436769  |
# | serial_timesteps   | 4608          |
# | time_elapsed       | 3.51          |
# | total_timesteps    | 4608          |
# | value_loss         | 1.2380142     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00035208405 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0867       |
# | fps                | 1347          |
# | n_updates          | 37            |
# | policy_entropy     | 1.3410127     |
# | policy_loss        | -0.0044419756 |
# | serial_timesteps   | 4736          |
# | time_elapsed       | 3.6           |
# | total_timesteps    | 4736          |
# | value_loss         | 0.7433604     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0001776239 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.0195      |
# | fps                | 1383         |
# | n_updates          | 38           |
# | policy_entropy     | 1.3386256    |
# | policy_loss        | -0.003405098 |
# | serial_timesteps   | 4864         |
# | time_elapsed       | 3.7          |
# | total_timesteps    | 4864         |
# | value_loss         | 0.898296     |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 0.000120289274 |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0931        |
# | fps                | 1347           |
# | n_updates          | 39             |
# | policy_entropy     | 1.3381968      |
# | policy_loss        | -0.005431097   |
# | serial_timesteps   | 4992           |
# | time_elapsed       | 3.8            |
# | total_timesteps    | 4992           |
# | value_loss         | 0.58966184     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00023720111 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0989        |
# | fps                | 1361          |
# | n_updates          | 40            |
# | policy_entropy     | 1.33424       |
# | policy_loss        | -0.0039704326 |
# | serial_timesteps   | 5120          |
# | time_elapsed       | 3.89          |
# | total_timesteps    | 5120          |
# | value_loss         | 2.240163      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0001269367  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0948        |
# | fps                | 1361          |
# | n_updates          | 41            |
# | policy_entropy     | 1.3343488     |
# | policy_loss        | -0.0042007547 |
# | serial_timesteps   | 5248          |
# | time_elapsed       | 3.99          |
# | total_timesteps    | 5248          |
# | value_loss         | 1.1539819     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00018705212 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0425       |
# | fps                | 1367          |
# | n_updates          | 42            |
# | policy_entropy     | 1.3352985     |
# | policy_loss        | -0.005780656  |
# | serial_timesteps   | 5376          |
# | time_elapsed       | 4.09          |
# | total_timesteps    | 5376          |
# | value_loss         | 1.2102444     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00018838432 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0239       |
# | fps                | 1406          |
# | n_updates          | 43            |
# | policy_entropy     | 1.3299831     |
# | policy_loss        | -0.0016052278 |
# | serial_timesteps   | 5504          |
# | time_elapsed       | 4.19          |
# | total_timesteps    | 5504          |
# | value_loss         | 2.5118685     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00014628738 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.11          |
# | fps                | 1391          |
# | n_updates          | 44            |
# | policy_entropy     | 1.3208956     |
# | policy_loss        | -0.0057408    |
# | serial_timesteps   | 5632          |
# | time_elapsed       | 4.28          |
# | total_timesteps    | 5632          |
# | value_loss         | 0.9885484     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00020469406 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.139         |
# | fps                | 1347          |
# | n_updates          | 45            |
# | policy_entropy     | 1.3185374     |
# | policy_loss        | -0.0066740178 |
# | serial_timesteps   | 5760          |
# | time_elapsed       | 4.37          |
# | total_timesteps    | 5760          |
# | value_loss         | 0.76084375    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00018260174 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.11          |
# | fps                | 1376          |
# | n_updates          | 46            |
# | policy_entropy     | 1.3110309     |
# | policy_loss        | -0.0036218446 |
# | serial_timesteps   | 5888          |
# | time_elapsed       | 4.47          |
# | total_timesteps    | 5888          |
# | value_loss         | 1.3333554     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00035679358 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.108         |
# | fps                | 1376          |
# | n_updates          | 47            |
# | policy_entropy     | 1.3166177     |
# | policy_loss        | -0.007854106  |
# | serial_timesteps   | 6016          |
# | time_elapsed       | 4.57          |
# | total_timesteps    | 6016          |
# | value_loss         | 0.80433285    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00045358285 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.062         |
# | fps                | 1391          |
# | n_updates          | 48            |
# | policy_entropy     | 1.3024125     |
# | policy_loss        | -0.0068869414 |
# | serial_timesteps   | 6144          |
# | time_elapsed       | 4.66          |
# | total_timesteps    | 6144          |
# | value_loss         | 1.0455003     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00038303446 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0169        |
# | fps                | 1359          |
# | n_updates          | 49            |
# | policy_entropy     | 1.2961888     |
# | policy_loss        | -0.006569875  |
# | serial_timesteps   | 6272          |
# | time_elapsed       | 4.76          |
# | total_timesteps    | 6272          |
# | value_loss         | 1.0118308     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0005792975 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.0944       |
# | fps                | 1347         |
# | n_updates          | 50           |
# | policy_entropy     | 1.2887686    |
# | policy_loss        | -0.009586196 |
# | serial_timesteps   | 6400         |
# | time_elapsed       | 4.85         |
# | total_timesteps    | 6400         |
# | value_loss         | 1.3523892    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00047125245 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.11          |
# | fps                | 1347          |
# | n_updates          | 51            |
# | policy_entropy     | 1.2799788     |
# | policy_loss        | -0.004876566  |
# | serial_timesteps   | 6528          |
# | time_elapsed       | 4.95          |
# | total_timesteps    | 6528          |
# | value_loss         | 0.66110563    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0007411079 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.148        |
# | fps                | 1292         |
# | n_updates          | 52           |
# | policy_entropy     | 1.2674758    |
# | policy_loss        | -0.010774009 |
# | serial_timesteps   | 6656         |
# | time_elapsed       | 5.05         |
# | total_timesteps    | 6656         |
# | value_loss         | 1.1793326    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0006013989 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.0572       |
# | fps                | 1276         |
# | n_updates          | 53           |
# | policy_entropy     | 1.2317569    |
# | policy_loss        | -0.005676914 |
# | serial_timesteps   | 6784         |
# | time_elapsed       | 5.15         |
# | total_timesteps    | 6784         |
# | value_loss         | 0.937629     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00040349126 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0474        |
# | fps                | 1333          |
# | n_updates          | 54            |
# | policy_entropy     | 1.2278577     |
# | policy_loss        | -0.008286038  |
# | serial_timesteps   | 6912          |
# | time_elapsed       | 5.25          |
# | total_timesteps    | 6912          |
# | value_loss         | 0.6578031     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0005581418  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00621      |
# | fps                | 1347          |
# | n_updates          | 55            |
# | policy_entropy     | 1.2272692     |
# | policy_loss        | -0.0060008913 |
# | serial_timesteps   | 7040          |
# | time_elapsed       | 5.35          |
# | total_timesteps    | 7040          |
# | value_loss         | 1.3678552     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00037496787 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.154         |
# | fps                | 1376          |
# | n_updates          | 56            |
# | policy_entropy     | 1.2089937     |
# | policy_loss        | -0.007579999  |
# | serial_timesteps   | 7168          |
# | time_elapsed       | 5.45          |
# | total_timesteps    | 7168          |
# | value_loss         | 0.93165326    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00018703839 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.126         |
# | fps                | 1347          |
# | n_updates          | 57            |
# | policy_entropy     | 1.1800196     |
# | policy_loss        | -0.0063905944 |
# | serial_timesteps   | 7296          |
# | time_elapsed       | 5.54          |
# | total_timesteps    | 7296          |
# | value_loss         | 1.6321129     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00064300076 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0323        |
# | fps                | 1333          |
# | n_updates          | 58            |
# | policy_entropy     | 1.1820242     |
# | policy_loss        | -0.01311595   |
# | serial_timesteps   | 7424          |
# | time_elapsed       | 5.64          |
# | total_timesteps    | 7424          |
# | value_loss         | 1.6599128     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0010399341 |
# | clipfrac           | 0.00390625   |
# | explained_variance | 0.0801       |
# | fps                | 1333         |
# | n_updates          | 59           |
# | policy_entropy     | 1.2331083    |
# | policy_loss        | -0.006837811 |
# | serial_timesteps   | 7552         |
# | time_elapsed       | 5.74         |
# | total_timesteps    | 7552         |
# | value_loss         | 1.4094199    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00018957024 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0472       |
# | fps                | 1319          |
# | n_updates          | 60            |
# | policy_entropy     | 1.2098194     |
# | policy_loss        | -0.003803049  |
# | serial_timesteps   | 7680          |
# | time_elapsed       | 5.84          |
# | total_timesteps    | 7680          |
# | value_loss         | 0.72831744    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0001464728 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.0239      |
# | fps                | 1361         |
# | n_updates          | 61           |
# | policy_entropy     | 1.208895     |
# | policy_loss        | -0.004792203 |
# | serial_timesteps   | 7808         |
# | time_elapsed       | 5.94         |
# | total_timesteps    | 7808         |
# | value_loss         | 0.83938926   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00016552412 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0541        |
# | fps                | 1361          |
# | n_updates          | 62            |
# | policy_entropy     | 1.2220371     |
# | policy_loss        | -0.0033287883 |
# | serial_timesteps   | 7936          |
# | time_elapsed       | 6.03          |
# | total_timesteps    | 7936          |
# | value_loss         | 3.523023      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00017742095 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0155       |
# | fps                | 1375          |
# | n_updates          | 63            |
# | policy_entropy     | 1.2315626     |
# | policy_loss        | -0.0053527523 |
# | serial_timesteps   | 8064          |
# | time_elapsed       | 6.13          |
# | total_timesteps    | 8064          |
# | value_loss         | 1.7093587     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00013393507 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.146         |
# | fps                | 1347          |
# | n_updates          | 64            |
# | policy_entropy     | 1.1899157     |
# | policy_loss        | -0.0028881547 |
# | serial_timesteps   | 8192          |
# | time_elapsed       | 6.22          |
# | total_timesteps    | 8192          |
# | value_loss         | 1.6932703     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 8.1892285e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0492       |
# | fps                | 1361          |
# | n_updates          | 65            |
# | policy_entropy     | 1.2101862     |
# | policy_loss        | -0.0034239697 |
# | serial_timesteps   | 8320          |
# | time_elapsed       | 6.32          |
# | total_timesteps    | 8320          |
# | value_loss         | 2.0515811     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.519196e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.15          |
# | fps                | 1391          |
# | n_updates          | 66            |
# | policy_entropy     | 1.1888093     |
# | policy_loss        | -0.0034868363 |
# | serial_timesteps   | 8448          |
# | time_elapsed       | 6.42          |
# | total_timesteps    | 8448          |
# | value_loss         | 2.0780973     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00015634709 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0123       |
# | fps                | 1391          |
# | n_updates          | 67            |
# | policy_entropy     | 1.2141297     |
# | policy_loss        | -0.0048951767 |
# | serial_timesteps   | 8576          |
# | time_elapsed       | 6.51          |
# | total_timesteps    | 8576          |
# | value_loss         | 3.187246      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 9.565492e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.00607     |
# | fps                | 1361         |
# | n_updates          | 68           |
# | policy_entropy     | 1.2227149    |
# | policy_loss        | -0.004459689 |
# | serial_timesteps   | 8704         |
# | time_elapsed       | 6.61         |
# | total_timesteps    | 8704         |
# | value_loss         | 3.6322482    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00024792698 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0124       |
# | fps                | 1347          |
# | n_updates          | 69            |
# | policy_entropy     | 1.1963297     |
# | policy_loss        | -0.006166267  |
# | serial_timesteps   | 8832          |
# | time_elapsed       | 6.7           |
# | total_timesteps    | 8832          |
# | value_loss         | 2.7230623     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00019244208 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0849       |
# | fps                | 1376          |
# | n_updates          | 70            |
# | policy_entropy     | 1.2108027     |
# | policy_loss        | -0.0043717073 |
# | serial_timesteps   | 8960          |
# | time_elapsed       | 6.8           |
# | total_timesteps    | 8960          |
# | value_loss         | 1.1797624     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00047984527 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.108         |
# | fps                | 1333          |
# | n_updates          | 71            |
# | policy_entropy     | 1.176543      |
# | policy_loss        | -0.0079436805 |
# | serial_timesteps   | 9088          |
# | time_elapsed       | 6.9           |
# | total_timesteps    | 9088          |
# | value_loss         | 1.2444451     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0008103671 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.0687      |
# | fps                | 1390         |
# | n_updates          | 72           |
# | policy_entropy     | 1.2176071    |
# | policy_loss        | -0.006175989 |
# | serial_timesteps   | 9216         |
# | time_elapsed       | 7            |
# | total_timesteps    | 9216         |
# | value_loss         | 0.611174     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00035199212 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00104      |
# | fps                | 1391          |
# | n_updates          | 73            |
# | policy_entropy     | 1.1969789     |
# | policy_loss        | -0.0031127813 |
# | serial_timesteps   | 9344          |
# | time_elapsed       | 7.09          |
# | total_timesteps    | 9344          |
# | value_loss         | 1.3416772     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00017243525 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00915      |
# | fps                | 1376          |
# | n_updates          | 74            |
# | policy_entropy     | 1.197345      |
# | policy_loss        | -0.006073473  |
# | serial_timesteps   | 9472          |
# | time_elapsed       | 7.19          |
# | total_timesteps    | 9472          |
# | value_loss         | 1.7291312     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0012573578 |
# | clipfrac           | 0.001953125  |
# | explained_variance | 0.0781       |
# | fps                | 1361         |
# | n_updates          | 75           |
# | policy_entropy     | 1.2081269    |
# | policy_loss        | -0.014168831 |
# | serial_timesteps   | 9600         |
# | time_elapsed       | 7.28         |
# | total_timesteps    | 9600         |
# | value_loss         | 0.58916944   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00029449922 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0871       |
# | fps                | 1361          |
# | n_updates          | 76            |
# | policy_entropy     | 1.2220938     |
# | policy_loss        | -0.0044680685 |
# | serial_timesteps   | 9728          |
# | time_elapsed       | 7.38          |
# | total_timesteps    | 9728          |
# | value_loss         | 0.55394125    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0005059579 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.000821     |
# | fps                | 1376         |
# | n_updates          | 77           |
# | policy_entropy     | 1.220489     |
# | policy_loss        | -0.007123601 |
# | serial_timesteps   | 9856         |
# | time_elapsed       | 7.47         |
# | total_timesteps    | 9856         |
# | value_loss         | 1.5739105    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00041565573 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0183        |
# | fps                | 1376          |
# | n_updates          | 78            |
# | policy_entropy     | 1.2237225     |
# | policy_loss        | -0.0076512247 |
# | serial_timesteps   | 9984          |
# | time_elapsed       | 7.57          |
# | total_timesteps    | 9984          |
# | value_loss         | 1.7243495     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00018521615 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00386      |
# | fps                | 1376          |
# | n_updates          | 79            |
# | policy_entropy     | 1.20663       |
# | policy_loss        | -0.001312121  |
# | serial_timesteps   | 10112         |
# | time_elapsed       | 7.66          |
# | total_timesteps    | 10112         |
# | value_loss         | 7.076123      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00012373798 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0447        |
# | fps                | 1391          |
# | n_updates          | 80            |
# | policy_entropy     | 1.2140735     |
# | policy_loss        | -0.005441725  |
# | serial_timesteps   | 10240         |
# | time_elapsed       | 7.76          |
# | total_timesteps    | 10240         |
# | value_loss         | 1.6350019     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00051006087 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0399       |
# | fps                | 1353          |
# | n_updates          | 81            |
# | policy_entropy     | 1.2063854     |
# | policy_loss        | -0.008644957  |
# | serial_timesteps   | 10368         |
# | time_elapsed       | 7.85          |
# | total_timesteps    | 10368         |
# | value_loss         | 1.9814394     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00038638795 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.117         |
# | fps                | 1391          |
# | n_updates          | 82            |
# | policy_entropy     | 1.1851852     |
# | policy_loss        | -0.004895696  |
# | serial_timesteps   | 10496         |
# | time_elapsed       | 7.95          |
# | total_timesteps    | 10496         |
# | value_loss         | 0.9635634     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00045173836 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0522        |
# | fps                | 1376          |
# | n_updates          | 83            |
# | policy_entropy     | 1.1915406     |
# | policy_loss        | -0.0074441144 |
# | serial_timesteps   | 10624         |
# | time_elapsed       | 8.04          |
# | total_timesteps    | 10624         |
# | value_loss         | 1.7783498     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0002607104  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.065         |
# | fps                | 1332          |
# | n_updates          | 84            |
# | policy_entropy     | 1.1756546     |
# | policy_loss        | -0.0074265157 |
# | serial_timesteps   | 10752         |
# | time_elapsed       | 8.14          |
# | total_timesteps    | 10752         |
# | value_loss         | 1.1238267     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00011451365 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0723        |
# | fps                | 1376          |
# | n_updates          | 85            |
# | policy_entropy     | 1.2115704     |
# | policy_loss        | -0.0033543592 |
# | serial_timesteps   | 10880         |
# | time_elapsed       | 8.24          |
# | total_timesteps    | 10880         |
# | value_loss         | 0.9436346     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00015917845 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0976       |
# | fps                | 1361          |
# | n_updates          | 86            |
# | policy_entropy     | 1.2138915     |
# | policy_loss        | -0.0045118798 |
# | serial_timesteps   | 11008         |
# | time_elapsed       | 8.33          |
# | total_timesteps    | 11008         |
# | value_loss         | 1.9075214     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0002513794  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0928        |
# | fps                | 1391          |
# | n_updates          | 87            |
# | policy_entropy     | 1.2084026     |
# | policy_loss        | -0.0073393453 |
# | serial_timesteps   | 11136         |
# | time_elapsed       | 8.43          |
# | total_timesteps    | 11136         |
# | value_loss         | 1.5860994     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00022576176 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0744        |
# | fps                | 1347          |
# | n_updates          | 88            |
# | policy_entropy     | 1.1797183     |
# | policy_loss        | -0.003226736  |
# | serial_timesteps   | 11264         |
# | time_elapsed       | 8.52          |
# | total_timesteps    | 11264         |
# | value_loss         | 2.1556628     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00035828486 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0596        |
# | fps                | 1361          |
# | n_updates          | 89            |
# | policy_entropy     | 1.2009604     |
# | policy_loss        | -0.0061916644 |
# | serial_timesteps   | 11392         |
# | time_elapsed       | 8.62          |
# | total_timesteps    | 11392         |
# | value_loss         | 0.9589764     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00010102539 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.122         |
# | fps                | 1398          |
# | n_updates          | 90            |
# | policy_entropy     | 1.2149955     |
# | policy_loss        | -0.0033106206 |
# | serial_timesteps   | 11520         |
# | time_elapsed       | 8.72          |
# | total_timesteps    | 11520         |
# | value_loss         | 1.5287828     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00016396586 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.142         |
# | fps                | 1376          |
# | n_updates          | 91            |
# | policy_entropy     | 1.1883184     |
# | policy_loss        | -0.005486807  |
# | serial_timesteps   | 11648         |
# | time_elapsed       | 8.81          |
# | total_timesteps    | 11648         |
# | value_loss         | 0.9862867     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00040808023 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.111         |
# | fps                | 1376          |
# | n_updates          | 92            |
# | policy_entropy     | 1.1768051     |
# | policy_loss        | -0.00907273   |
# | serial_timesteps   | 11776         |
# | time_elapsed       | 8.9           |
# | total_timesteps    | 11776         |
# | value_loss         | 0.8293142     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0005730955  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.15          |
# | fps                | 1376          |
# | n_updates          | 93            |
# | policy_entropy     | 1.1694239     |
# | policy_loss        | -0.0089336345 |
# | serial_timesteps   | 11904         |
# | time_elapsed       | 9             |
# | total_timesteps    | 11904         |
# | value_loss         | 1.2326858     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00040147066 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0596        |
# | fps                | 1376          |
# | n_updates          | 94            |
# | policy_entropy     | 1.1367825     |
# | policy_loss        | -0.007521076  |
# | serial_timesteps   | 12032         |
# | time_elapsed       | 9.09          |
# | total_timesteps    | 12032         |
# | value_loss         | 0.74740916    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00013660906 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.178         |
# | fps                | 1376          |
# | n_updates          | 95            |
# | policy_entropy     | 1.1835186     |
# | policy_loss        | -0.003005645  |
# ...
# | explained_variance | 0.191         |
# | fps                | 1391          |
# | n_updates          | 522           |
# | policy_entropy     | 0.3976856     |
# | policy_loss        | -0.0033392427 |
# | serial_timesteps   | 66816         |
# | time_elapsed       | 49.1          |
# | total_timesteps    | 66816         |
# | value_loss         | 3.2890687     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00021888192 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0305        |
# | fps                | 1391          |
# | n_updates          | 523           |
# | policy_entropy     | 0.41229743    |
# | policy_loss        | -0.0017736458 |
# | serial_timesteps   | 66944         |
# | time_elapsed       | 49.2          |
# | total_timesteps    | 66944         |
# | value_loss         | 9.175665      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00015955306 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.309         |
# | fps                | 1376          |
# | n_updates          | 524           |
# | policy_entropy     | 0.41402745    |
# | policy_loss        | -0.0058139786 |
# | serial_timesteps   | 67072         |
# | time_elapsed       | 49.3          |
# | total_timesteps    | 67072         |
# | value_loss         | 5.637762      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00024334961 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.163         |
# | fps                | 1406          |
# | n_updates          | 525           |
# | policy_entropy     | 0.40767658    |
# | policy_loss        | -0.004603628  |
# | serial_timesteps   | 67200         |
# | time_elapsed       | 49.4          |
# | total_timesteps    | 67200         |
# | value_loss         | 1.4077473     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00068333675 |
# | clipfrac           | 0.00390625    |
# | explained_variance | 0.365         |
# | fps                | 1406          |
# | n_updates          | 526           |
# | policy_entropy     | 0.40318838    |
# | policy_loss        | -0.0067926124 |
# | serial_timesteps   | 67328         |
# | time_elapsed       | 49.5          |
# | total_timesteps    | 67328         |
# | value_loss         | 1.1822076     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00068078446 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.118        |
# | fps                | 1391          |
# | n_updates          | 527           |
# | policy_entropy     | 0.40947488    |
# | policy_loss        | -0.006211317  |
# | serial_timesteps   | 67456         |
# | time_elapsed       | 49.6          |
# | total_timesteps    | 67456         |
# | value_loss         | 6.908013      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00044795466 |
# | clipfrac           | 0.00390625    |
# | explained_variance | 0.43          |
# | fps                | 1422          |
# | n_updates          | 528           |
# | policy_entropy     | 0.40111205    |
# | policy_loss        | -0.00464711   |
# | serial_timesteps   | 67584         |
# | time_elapsed       | 49.7          |
# | total_timesteps    | 67584         |
# | value_loss         | 1.9957331     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00012687483 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.12          |
# | fps                | 1406          |
# | n_updates          | 529           |
# | policy_entropy     | 0.4135259     |
# | policy_loss        | -0.002732043  |
# | serial_timesteps   | 67712         |
# | time_elapsed       | 49.8          |
# | total_timesteps    | 67712         |
# | value_loss         | 7.196028      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00023949501 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.307         |
# | fps                | 1391          |
# | n_updates          | 530           |
# | policy_entropy     | 0.32696852    |
# | policy_loss        | -0.0033385118 |
# | serial_timesteps   | 67840         |
# | time_elapsed       | 49.9          |
# | total_timesteps    | 67840         |
# | value_loss         | 3.0759592     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00024535265 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.352         |
# | fps                | 1438          |
# | n_updates          | 531           |
# | policy_entropy     | 0.3872037     |
# | policy_loss        | -0.006092173  |
# | serial_timesteps   | 67968         |
# | time_elapsed       | 50            |
# | total_timesteps    | 67968         |
# | value_loss         | 4.7163377     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00033195334 |
# | clipfrac           | 0.00390625    |
# | explained_variance | 0.342         |
# | fps                | 1376          |
# | n_updates          | 532           |
# | policy_entropy     | 0.36646396    |
# | policy_loss        | -0.003855006  |
# | serial_timesteps   | 68096         |
# | time_elapsed       | 50            |
# | total_timesteps    | 68096         |
# | value_loss         | 3.7174847     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00016575218 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.189         |
# | fps                | 1376          |
# | n_updates          | 533           |
# | policy_entropy     | 0.35399437    |
# | policy_loss        | -0.0018821144 |
# | serial_timesteps   | 68224         |
# | time_elapsed       | 50.1          |
# | total_timesteps    | 68224         |
# | value_loss         | 1.779555      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00017373778 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.507        |
# | fps                | 1414          |
# | n_updates          | 534           |
# | policy_entropy     | 0.36080202    |
# | policy_loss        | -0.0020941254 |
# | serial_timesteps   | 68352         |
# | time_elapsed       | 50.2          |
# | total_timesteps    | 68352         |
# | value_loss         | 0.35381374    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00029167754 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.134         |
# | fps                | 1413          |
# | n_updates          | 535           |
# | policy_entropy     | 0.40169203    |
# | policy_loss        | -0.0036655758 |
# | serial_timesteps   | 68480         |
# | time_elapsed       | 50.3          |
# | total_timesteps    | 68480         |
# | value_loss         | 2.237309      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00069561193 |
# | clipfrac           | 0.00390625    |
# | explained_variance | 0.179         |
# | fps                | 1391          |
# | n_updates          | 536           |
# | policy_entropy     | 0.3836125     |
# | policy_loss        | -0.0045469836 |
# | serial_timesteps   | 68608         |
# | time_elapsed       | 50.4          |
# | total_timesteps    | 68608         |
# | value_loss         | 2.1905534     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00064011815 |
# | clipfrac           | 0.005859375   |
# | explained_variance | 0.0387        |
# | fps                | 1391          |
# | n_updates          | 537           |
# | policy_entropy     | 0.3924919     |
# | policy_loss        | -0.009521589  |
# | serial_timesteps   | 68736         |
# | time_elapsed       | 50.5          |
# | total_timesteps    | 68736         |
# | value_loss         | 3.8005335     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.000931129  |
# | clipfrac           | 0.0078125    |
# | explained_variance | 0.262        |
# | fps                | 1422         |
# | n_updates          | 538          |
# | policy_entropy     | 0.41243935   |
# | policy_loss        | -0.007752113 |
# | serial_timesteps   | 68864        |
# | time_elapsed       | 50.6         |
# | total_timesteps    | 68864        |
# | value_loss         | 2.3240068    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0003042902  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.138         |
# | fps                | 1438          |
# | n_updates          | 539           |
# | policy_entropy     | 0.3618106     |
# | policy_loss        | -0.0032401741 |
# | serial_timesteps   | 68992         |
# | time_elapsed       | 50.7          |
# | total_timesteps    | 68992         |
# | value_loss         | 3.2459157     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0008903059 |
# | clipfrac           | 0.013671875  |
# | explained_variance | -0.0231      |
# | fps                | 1406         |
# | n_updates          | 540          |
# | policy_entropy     | 0.39282426   |
# | policy_loss        | -0.012784788 |
# | serial_timesteps   | 69120        |
# | time_elapsed       | 50.8         |
# | total_timesteps    | 69120        |
# | value_loss         | 2.0387726    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00041393028 |
# | clipfrac           | 0.001953125   |
# | explained_variance | -0.25         |
# | fps                | 1406          |
# | n_updates          | 541           |
# | policy_entropy     | 0.35746908    |
# | policy_loss        | -0.003369828  |
# | serial_timesteps   | 69248         |
# | time_elapsed       | 50.9          |
# | total_timesteps    | 69248         |
# | value_loss         | 2.457677      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00018836922 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.279         |
# | fps                | 1391          |
# | n_updates          | 542           |
# | policy_entropy     | 0.32864425    |
# | policy_loss        | -0.0032683155 |
# | serial_timesteps   | 69376         |
# | time_elapsed       | 51            |
# | total_timesteps    | 69376         |
# | value_loss         | 5.3312736     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00024657958 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.416         |
# | fps                | 1391          |
# | n_updates          | 543           |
# | policy_entropy     | 0.33691967    |
# | policy_loss        | -0.002402078  |
# | serial_timesteps   | 69504         |
# | time_elapsed       | 51.1          |
# | total_timesteps    | 69504         |
# | value_loss         | 1.3874106     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00021555898 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.34          |
# | fps                | 1406          |
# | n_updates          | 544           |
# | policy_entropy     | 0.3293259     |
# | policy_loss        | -0.002609477  |
# | serial_timesteps   | 69632         |
# | time_elapsed       | 51.2          |
# | total_timesteps    | 69632         |
# | value_loss         | 1.4894267     |
# --------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# A:\Avans\RL-Snake\ppo2.py in <module>
#      42                  n_steps=int(properties['n_steps'])
#      43     )
# ---> 44     model.learn(1000000)
#      45     model.save('learned_models/snake_ppo2')
#      46 else:
#
# C:\ProgramData\Anaconda3\envs\py37\lib\site-packages\stable_baselines\ppo2\ppo2.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps)
#     334                 callback.on_rollout_start()
#     335                 # true_reward is the reward without discount
# --> 336                 rollout = self.runner.run(callback)
#     337                 # Unpack
#     338                 obs, returns, masks, actions, values, neglogpacs, states, ep_infos, true_reward = rollout
#
# C:\ProgramData\Anaconda3\envs\py37\lib\site-packages\stable_baselines\common\runners.py in run(self, callback)
#      46         self.callback = callback
#      47         self.continue_training = True
# ---> 48         return self._run()
#      49
#      50     @abstractmethod
#
# C:\ProgramData\Anaconda3\envs\py37\lib\site-packages\stable_baselines\ppo2\ppo2.py in _run(self)
#     470         ep_infos = []
#     471         for _ in range(self.n_steps):
# --> 472             actions, values, self.states, neglogpacs = self.model.step(self.obs, self.states, self.dones)  # pytype: disable=attribute-error
#     473             mb_obs.append(self.obs.copy())
#     474             mb_actions.append(actions)
#
# C:\ProgramData\Anaconda3\envs\py37\lib\site-packages\stable_baselines\common\policies.py in step(self, obs, state, mask, deterministic)
#     574         else:
#     575             action, value, neglogp = self.sess.run([self.action, self.value_flat, self.neglogp],
# --> 576                                                    {self.obs_ph: obs})
#     577         return action, value, self.initial_state, neglogp
#     578
#
# C:\ProgramData\Anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\ProgramData\Anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# C:\ProgramData\Anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# C:\ProgramData\Anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\client\session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# C:\ProgramData\Anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# C:\ProgramData\Anaconda3\envs\py37\lib\site-packages\tensorflow_core\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# # Choosing reward values
# We tried using different reward for the snake, first we started off with +1 for getting an apple -1 for dying.
# Then we tried protecting the snake from dying by increasing the negative reward for dying to -10.
# But the snake wasn’t getting good results so we tried adding an negative reward -0.5 for making a step with no apple on it.
# But that didn’t work as expected, so we went back to +1 for getting an apple -1 for dying.
#
# | Option | Dead | Apple | Nothing | Amount of apples |
# | --- | --- | --- | --- | --- |
# | 1 | -1 | 1 | 0 | 1 |
# | 2 | -10 | 1 | 0 | 1 |
# | 3 | -10 | 1 | 1/grid size | 1 |
# | 4 | -1  | 3 | 0 | 1 |
# | 5 | 10 | 1 | 0.1 | 1 |
# | 6 | 10 | 3 | 1/grid size | 1 |
# | 7 | 1 | 3 | 1/grid size | 1 |
# | 8 | 1 | 3 | 0 | 3 |
#
# results:
# 1: Noticeable low, wont get much higher than 0
# 2: Good result, gets 4-5 apples and dies
# 3: Good result, gets 38-41 reward (13-14 apples, minus 1 for dead)
# 4: Comparable with 2
# 5: Mediocre, between 1-2
# 6: Gets a positive value, But doesn't get much above 2
# 7: Decent result, has a minor tendency to run into walls

# %% [markdown]
# # Option 1 (DQN D:-1, A:1, N:0)

# %%
# %matplotlib notebook
# %run dqn.py train=False load_model=DQN_2
# Out:
# Using properties:
# -  train : False
# -  steps : 30
# -  learning_rate : 0.001
# -  double_q : True
# -  grid_size : 6
# -  exploration_factor : 0.1
# -  exploration_min : 0.02
# -  total_steps : 400000
# -  load_model : DQN_2
# Loading a model without an environment, this model cannot be trained until it has a valid environment.
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Option 4 (PPO2 D:-10, A:1, N:1/grid): Run \#1

# %%
# %matplotlib notebook
# %run ppo2.py train=False load_model=PPO2_3_R1
# Out:
# Using properties:
# -  train : False
# -  steps : 200
# -  grid_size : 6
# -  n_steps : 128
# -  load_model : PPO2_3_R1
# Loading a model without an environment, this model cannot be trained until it has a valid environment.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\py37\lib\site-packages\stable_baselines\common\distributions.py:327: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\py37\lib\site-packages\stable_baselines\ppo2\ppo2.py:198: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\py37\lib\site-packages\stable_baselines\ppo2\ppo2.py:240: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Option 4 (PPO2 D:-10, A:1, N:1/grid): Run \#2

# %%
# %matplotlib notebook
# %run ppo2.py train=False load_model=PPO2_3_R2
# Out:
# Using properties:
# -  train : False
# -  steps : 200
# -  grid_size : 6
# -  n_steps : 128
# -  load_model : PPO2_3_R2
# Loading a model without an environment, this model cannot be trained until it has a valid environment.
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Option 4 (PPO2 D:-10, A:1, N:1/grid): Run \#3, 20mil episodes

# %%
# %matplotlib notebook
# %run ppo2.py train=False load_model=PPO2_3_R3_20MIL
# Out:
# Using properties:
# -  train : False
# -  steps : 200
# -  grid_size : 6
# -  n_steps : 128
# -  load_model : PPO2_3_R3_20MIL
# Loading a model without an environment, this model cannot be trained until it has a valid environment.
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Option 8 (PPO2 D:-1, A:3, N:0): 3 apples

# %%
# %matplotlib notebook
# %run ppo2.py train=False load_model=snake_ppo2 steps=500
# Out:
# Using properties:
# -  train : False
# -  steps : 500
# -  grid_size : 6
# -  n_steps : 128
# -  load_model : snake_ppo2
# Loading a model without an environment, this model cannot be trained until it has a valid environment.
# <img src="data:image/png;base64,..." width="640">
