# %%
# %matplotlib notebook
# %run base.py

# %%
# %matplotlib notebook
# %run expert.py

# %%
# %matplotlib notebook
# %run dqn.py
# Out:
# Using properties:
# -  train : True
# -  steps : 30
# -  learning_rate : 0.001
# -  double_q : True
# -  grid_size : 6
# -  exploration_factor : 0.1
# -  exploration_min : 0.02
# --------------------------------------
# | % time spent exploring  | 97       |
# | episodes                | 100      |
# | mean 100 episode reward | -9.8     |
# | steps                   | 831      |
# --------------------------------------
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\py37\lib\site-packages\stable_baselines\deepq\dqn.py:284: The name tf.RunOptions is deprecated. Please use tf.compat.v1.RunOptions instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\py37\lib\site-packages\stable_baselines\deepq\dqn.py:285: The name tf.RunMetadata is deprecated. Please use tf.compat.v1.RunMetadata instead.
#
# --------------------------------------
# | % time spent exploring  | 96       |
# | episodes                | 200      |
# | mean 100 episode reward | -9.9     |
# ...
