# %%
# %matplotlib notebook
# %run main.py
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
# %run expert.py
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
# %run dqn.py
