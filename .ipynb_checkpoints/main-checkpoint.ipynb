# %%
# %matplotlib notebook
# %run base.py
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
# %run expert.py
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# A:\Avans\RL-Snake\expert.py in <module>
#      49 done = False
#      50 while ~done:
# ---> 51     env.render(frame_speed=.05)
#      52     x_snek, y_snek = get_object(obs, HEAD)
#      53     x_apple, y_apple = get_object(obs, APPLE)
#
# A:\Avans\RL-Snake\gym_snake\envs\snake_env.py in render(self, mode, close, frame_speed)
#     131             self.viewer.clear()
#     132             self.viewer.imshow(self.last_obs)
# --> 133             plt.pause(frame_speed)
#     134         self.fig.canvas.draw()
#     135
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in pause(interval)
#     436             canvas.draw_idle()
#     437         show(block=False)
# --> 438         canvas.start_event_loop(interval)
#     439     else:
# ...

# %%
# %matplotlib notebook
# %run dqn.py
